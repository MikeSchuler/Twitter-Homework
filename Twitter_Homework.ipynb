# %%
import tweepy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import style
from datetime import datetime
import time
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key,
                    consumer_secret,
                    access_token,
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user1 = "@NYtimes"
target_user2 = "@BBC"
target_user3 = "@CNN"
target_user4 = "@FoxNews"
target_user5 = "@CBSNews"

sentiments1 = []
sentiments2 = []
sentiments3 = []
sentiments4 = []
sentiments5 = []

counter = 1

oldest_tweet = None

# for user in 
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user1, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments1.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments1_pd = pd.DataFrame.from_dict(sentiments1)
# sentiments1_pd.info()
sentiments1_pd.sort_values('Date', ascending=False).head()                                   
# sentiments2_pd.head()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 18   -0.1027  Thu Oct 04 23:47:05 +0000 2018     0.915    0.085     0.000
# 19    0.0000  Thu Oct 04 23:17:04 +0000 2018     1.000    0.000     0.000
# 20    0.0000  Thu Oct 04 23:06:06 +0000 2018     1.000    0.000     0.000
# 21    0.4522  Thu Oct 04 22:51:03 +0000 2018     0.871    0.000     0.129
# 22   -0.4404  Thu Oct 04 22:37:04 +0000 2018     0.879    0.121     0.000
#
#     Tweets Ago     User
# 18          19  nytimes
# 19          20  nytimes
# 20          21  nytimes
# 21          22  nytimes
# 22          23  nytimes

# %%
counter = 1
oldest_tweet = None

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user2, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
     
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments2.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments2_pd = pd.DataFrame.from_dict(sentiments2)
# sentiments2_pd.info()
sentiments2_pd.sort_values('Date', ascending=False).head()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 16    0.4939  Wed Oct 03 19:04:04 +0000 2018     0.819      0.0     0.181
# 17    0.0000  Wed Oct 03 17:59:01 +0000 2018     1.000      0.0     0.000
# 18    0.0000  Wed Oct 03 17:03:42 +0000 2018     1.000      0.0     0.000
# 19    0.4404  Wed Oct 03 16:55:01 +0000 2018     0.861      0.0     0.139
# 20    0.0000  Wed Oct 03 15:58:03 +0000 2018     1.000      0.0     0.000
#
#     Tweets Ago User
# 16          17  BBC
# 17          18  BBC
# 18          19  BBC
# 19          20  BBC
# 20          21  BBC

# %%
counter = 1
oldest_tweet = None

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user3, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments3.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments3_pd = pd.DataFrame.from_dict(sentiments3)
# sentiments3_pd.head()
sentiments3_pd.sort_values('Date', ascending=False).head()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 50   -0.4588  Thu Oct 04 23:57:06 +0000 2018     0.875    0.125     0.000
# 51    0.5994  Thu Oct 04 23:46:00 +0000 2018     0.804    0.000     0.196
# 52    0.4019  Thu Oct 04 23:40:41 +0000 2018     0.828    0.000     0.172
# 53    0.4404  Thu Oct 04 23:34:42 +0000 2018     0.818    0.000     0.182
# 54    0.3400  Thu Oct 04 23:32:17 +0000 2018     0.756    0.092     0.151
#
#     Tweets Ago User
# 50          51  CNN
# 51          52  CNN
# 52          53  CNN
# 53          54  CNN
# 54          55  CNN

# %%
counter = 1
oldest_tweet = None

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user4, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments4.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments4_pd = pd.DataFrame.from_dict(sentiments4)
sentiments4_pd.sort_values('Date', ascending=False).head()
# sentiments4_pd.head()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 28   -0.4404  Thu Oct 04 23:51:21 +0000 2018     0.828    0.172     0.000
# 29    0.7845  Thu Oct 04 23:50:28 +0000 2018     0.574    0.109     0.317
# 30    0.2716  Thu Oct 04 23:46:10 +0000 2018     0.901    0.000     0.099
# 31    0.0000  Thu Oct 04 23:42:21 +0000 2018     1.000    0.000     0.000
# 32    0.0000  Thu Oct 04 23:38:08 +0000 2018     1.000    0.000     0.000
#
#     Tweets Ago     User
# 28          29  FoxNews
# 29          30  FoxNews
# 30          31  FoxNews
# 31          32  FoxNews
# 32          33  FoxNews

# %%
counter = 1
oldest_tweet = None

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user5, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments5.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments5_pd = pd.DataFrame.from_dict(sentiments5)
sentiments5_pd.sort_values('Date', ascending=False).head()
# sentiments5_pd.head()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 12   -0.2960  Thu Oct 04 23:54:54 +0000 2018     0.872    0.128     0.000
# 13    0.4404  Thu Oct 04 23:40:30 +0000 2018     0.854    0.000     0.146
# 14   -0.3182  Thu Oct 04 23:34:40 +0000 2018     0.827    0.173     0.000
# 15   -0.2585  Thu Oct 04 23:15:23 +0000 2018     0.898    0.102     0.000
# 16    0.0000  Thu Oct 04 23:11:33 +0000 2018     1.000    0.000     0.000
#
#     Tweets Ago     User
# 12          13  CBSNews
# 13          14  CBSNews
# 14          15  CBSNews
# 15          16  CBSNews
# 16          17  CBSNews

# %%
date = time.strftime("%m/%d/%Y")

plt.scatter(sentiments1_pd['Tweets Ago'], sentiments1_pd['Compound'], color='blue', alpha=.7, label='@NYTimes', edgecolors='black', s=50)
plt.scatter(sentiments2_pd['Tweets Ago'], sentiments2_pd['Compound'], color='yellow', alpha=.7, label='@BBC', edgecolors='black', s=50)
plt.scatter(sentiments3_pd['Tweets Ago'], sentiments3_pd['Compound'], color='red', alpha=.7, label='@CNN', edgecolors='black', s=50)
plt.scatter(sentiments4_pd['Tweets Ago'], sentiments4_pd['Compound'], color='green', alpha=.7, label='@FoxNews', edgecolors='black', s=50)
plt.scatter(sentiments5_pd['Tweets Ago'], sentiments5_pd['Compound'], color='purple', alpha=.7, label='@CBSNews', edgecolors='black', s=50)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))
plt.title(f"Sentiment Analysis of Media Tweets (" + date + ")")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
# @nytimes, @BBC, @CNN, @FoxNews, @CBSNews

target_users = ("@NYtimes", "@BBC", "@CNN", "@FoxNews", "@CBSNews")

# List for dictionaries of results
results_list = []

# Loop through each user
for user in target_users:

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Loop through 100 tweets
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(user, page=x, count=100)

        # Loop through all tweets
        for tweet in public_tweets:

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]

            # Add each value to the appropriate list
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)

    # Create a dictionaty of results
    user_results = {
        "Username": user,
        "Compound Score": np.mean(compound_list),
        "Postive Score": np.mean(positive_list),
        "Neutral Score": np.mean(neutral_list),
        "Negative Score": np.mean(negative_list)
    }

    # Append dictionary to list
    results_list.append(user_results)

    # Print the Averages
    print(f"User: {user}")
    print(f"Compound: {np.mean(compound_list):.3f}")
    print(f"Positive: {np.mean(positive_list):.3f}")
    print(f"Neutral: {np.mean(neutral_list):.3f}")
    print(f"Negative: {np.mean(negative_list):.3f}")
# Out:
# User: @NYtimes
# Compound: 0.008
# Positive: 0.066
# Neutral: 0.869
# Negative: 0.065
# User: @BBC
# Compound: 0.111
# Positive: 0.102
# Neutral: 0.839
# Negative: 0.058
# User: @CNN
# Compound: -0.017
# Positive: 0.066
# Neutral: 0.862
# Negative: 0.072
# User: @FoxNews
# Compound: -0.021
# Positive: 0.068
# Neutral: 0.851
# Negative: 0.081
# User: @CBSNews
# Compound: -0.053
# Positive: 0.067
# Neutral: 0.837
# Negative: 0.096

# %%
# Create DataFrame from Results List
results_df = pd.DataFrame(results_list).set_index("Username").round(3)
results_df
# Out:
#           Compound Score  Negative Score  Neutral Score  Postive Score
# Username
# @NYtimes           0.008           0.065          0.869          0.066
# @BBC               0.111           0.058          0.839          0.102
# @CNN              -0.017           0.072          0.862          0.066
# @FoxNews          -0.021           0.081          0.851          0.068
# @CBSNews          -0.053           0.096          0.837          0.067

# %%
colors = ['blue', 'yellow', 'red', 'green', 'purple']

date = time.strftime("%m/%d/%Y")

plt.bar(results_df.index, results_df['Compound Score'], color=colors, width=.9)
plt.title("Overall Media Sentiment on Twitter (" + date + ")")
plt.ylabel("Tweet Polarity")
plt.grid(False)
plt.show()
