# %%
import tweepy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import style
from datetime import datetime
import time
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key,
                    consumer_secret,
                    access_token,
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user1 = "@NYtimes"
target_user2 = "@BBC"
target_user3 = "@CNN"
target_user4 = "@FoxNews"
target_user5 = "@CBSNews"

sentiments1 = []
sentiments2 = []
sentiments3 = []
sentiments4 = []
sentiments5 = []

counter = 1

oldest_tweet = None

# for user in 
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user1, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments1.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments1_pd = pd.DataFrame.from_dict(sentiments1)
# sentiments1_pd.info()
sentiments1_pd.sort_values('Date', ascending=False).head()                                   
# sentiments2_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.4522  Thu Oct 04 22:51:03 +0000 2018     0.871    0.000     0.129
# 1   -0.4404  Thu Oct 04 22:37:04 +0000 2018     0.879    0.121     0.000
# 2    0.7351  Thu Oct 04 22:33:04 +0000 2018     0.721    0.000     0.279
# 3   -0.4767  Thu Oct 04 22:20:51 +0000 2018     0.860    0.140     0.000
# 4   -0.4939  Thu Oct 04 22:15:40 +0000 2018     0.856    0.144     0.000
#
#    Tweets Ago     User
# 0           1  nytimes
# 1           2  nytimes
# 2           3  nytimes
# 3           4  nytimes
# 4           5  nytimes

# %%
counter = 1

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user2, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
     
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments2.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments2_pd = pd.DataFrame.from_dict(sentiments2)
# sentiments2_pd.info()
sentiments2_pd.sort_values('Date', ascending=False).head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.4939  Wed Oct 03 19:04:04 +0000 2018     0.819      0.0     0.181
# 1    0.0000  Wed Oct 03 17:59:01 +0000 2018     1.000      0.0     0.000
# 2    0.0000  Wed Oct 03 17:03:42 +0000 2018     1.000      0.0     0.000
# 3    0.4404  Wed Oct 03 16:55:01 +0000 2018     0.861      0.0     0.139
# 4    0.0000  Wed Oct 03 15:58:03 +0000 2018     1.000      0.0     0.000
#
#    Tweets Ago User
# 0           1  BBC
# 1           2  BBC
# 2           3  BBC
# 3           4  BBC
# 4           5  BBC

# %%
counter = 1

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user3, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments3.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments3_pd = pd.DataFrame.from_dict(sentiments3)
# sentiments3_pd.head()
sentiments3_pd.sort_values('Date', ascending=False).head()
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 71   -0.4215  Wed Sep 26 23:47:22 +0000 2018     0.684    0.197     0.120
# 72    0.0000  Wed Sep 26 23:38:19 +0000 2018     1.000    0.000     0.000
# 73   -0.5106  Wed Sep 26 23:19:16 +0000 2018     0.837    0.163     0.000
# 74   -0.3400  Wed Sep 26 23:10:31 +0000 2018     0.870    0.130     0.000
# 75    0.5106  Wed Sep 26 22:58:52 +0000 2018     0.823    0.000     0.177
#
#     Tweets Ago User
# 71          72  CNN
# 72          73  CNN
# 73          74  CNN
# 74          75  CNN
# 75          76  CNN

# %%
counter = 1

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user4, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments4.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments4_pd = pd.DataFrame.from_dict(sentiments4)
sentiments4_pd.sort_values('Date', ascending=False).head()
# sentiments4_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Wed Sep 26 20:06:07 +0000 2018     1.000    0.000       0.0
# 1   -0.6705  Wed Sep 26 19:47:02 +0000 2018     0.640    0.360       0.0
# 2    0.0000  Wed Sep 26 19:30:05 +0000 2018     1.000    0.000       0.0
# 3    0.0000  Wed Sep 26 19:17:58 +0000 2018     1.000    0.000       0.0
# 4   -0.6124  Wed Sep 26 19:10:54 +0000 2018     0.792    0.208       0.0
#
#    Tweets Ago     User
# 0           1  FoxNews
# 1           2  FoxNews
# 2           3  FoxNews
# 3           4  FoxNews
# 4           5  FoxNews

# %%
counter = 1

for x in range(5):
    
    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user5, max_id = oldest_tweet)
    
    # Loop through all tweets 
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments5.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter,
                           "User": tweet['user']['screen_name']})
        
        # Add to counter 
        counter += 1

# %%
sentiments5_pd = pd.DataFrame.from_dict(sentiments5)
sentiments5_pd.sort_values('Date', ascending=False).head()
# sentiments5_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.6369  Wed Sep 26 08:03:04 +0000 2018     0.656    0.000     0.344
# 1   -0.6808  Wed Sep 26 07:48:03 +0000 2018     0.765    0.235     0.000
# 2   -0.7579  Wed Sep 26 07:33:03 +0000 2018     0.629    0.371     0.000
# 3    0.0000  Wed Sep 26 07:18:03 +0000 2018     1.000    0.000     0.000
# 4    0.0000  Wed Sep 26 07:03:04 +0000 2018     1.000    0.000     0.000
#
#    Tweets Ago     User
# 0           1  CBSNews
# 1           2  CBSNews
# 2           3  CBSNews
# 3           4  CBSNews
# 4           5  CBSNews

# %%
date = time.strftime("%m/%d/%Y")

plt.scatter(sentiments1_pd['Tweets Ago'], sentiments1_pd['Compound'], color='blue', alpha=.7, label='@NYTimes', edgecolors='black', s=50)
plt.scatter(sentiments2_pd['Tweets Ago'], sentiments2_pd['Compound'], color='yellow', alpha=.7, label='@BBC', edgecolors='black', s=50)
plt.scatter(sentiments3_pd['Tweets Ago'], sentiments3_pd['Compound'], color='red', alpha=.7, label='@CNN', edgecolors='black', s=50)
plt.scatter(sentiments4_pd['Tweets Ago'], sentiments4_pd['Compound'], color='green', alpha=.7, label='@FoxNews', edgecolors='black', s=50)
plt.scatter(sentiments5_pd['Tweets Ago'], sentiments5_pd['Compound'], color='purple', alpha=.7, label='@CBSNews', edgecolors='black', s=50)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))
plt.title(f"Sentiment Analysis of Media Tweets (" + date + ")")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
target_users = ("@NYtimes", "@BBC", "@CNN", "@FoxNews", "@CBSNews")


# Variables for holding sentiments
sentiments = []

for user in target_users:
    counter = 1

    # Variable for holding the oldest tweet
    oldest_tweet = None

     # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    counter_list=[]

    # Loop through 5 pages of tweets (total 100 tweets)
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(user, max_id= oldest_tweet)

        # Loop through all tweets 
        for tweet in public_tweets:
        
        # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]
            tweets_ago= counter
            
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)
            counter_list.append(tweets_ago)
            
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
            oldest_tweet = tweet['id'] - 1
        
        # Add to counter 
            counter += 1
            
        sentiments.append({"User": user,"Compound": compound_list,"Positive": positive_list,
                           "Negative": negative_list,"Neutral": neutral_list,"Tweets Ago": counter_list})
        
            #counter += 1

# %%
#sentiments

# %%
sentiments_pd = pd.DataFrame.from_dict(sentiments)
#sentiments_pd.sort_values(by=["Date"], ascending=False, inplace=True)
sentiments_pd.head()
# Out:
#                                             Compound  \
# 0  [0.4522, -0.4404, 0.7351, -0.4767, -0.4939, 0....
# 1  [0.4522, -0.4404, 0.7351, -0.4767, -0.4939, 0....
# 2  [0.4522, -0.4404, 0.7351, -0.4767, -0.4939, 0....
# 3  [0.4522, -0.4404, 0.7351, -0.4767, -0.4939, 0....
# 4  [0.4522, -0.4404, 0.7351, -0.4767, -0.4939, 0....
#
#                                             Negative  \
# 0  [0.0, 0.121, 0.0, 0.14, 0.144, 0.0, 0.13, 0.10...
# 1  [0.0, 0.121, 0.0, 0.14, 0.144, 0.0, 0.13, 0.10...
# 2  [0.0, 0.121, 0.0, 0.14, 0.144, 0.0, 0.13, 0.10...
# 3  [0.0, 0.121, 0.0, 0.14, 0.144, 0.0, 0.13, 0.10...
# 4  [0.0, 0.121, 0.0, 0.14, 0.144, 0.0, 0.13, 0.10...
#
#                                              Neutral  \
# 0  [0.871, 0.879, 0.721, 0.86, 0.856, 1.0, 0.87, ...
# 1  [0.871, 0.879, 0.721, 0.86, 0.856, 1.0, 0.87, ...
# 2  [0.871, 0.879, 0.721, 0.86, 0.856, 1.0, 0.87, ...
# 3  [0.871, 0.879, 0.721, 0.86, 0.856, 1.0, 0.87, ...
# ...

# %%
#sentiments_pd["Tweets Ago"]

# %%
date = time.strftime("%m/%d/%Y")
labels = ["@NYtimes", "@BBC", "@CNN", "@FoxNews", "@CBSNews"]
colors = ['blue', 'yellow', 'red', 'green', 'purple']


plt.scatter(sentiments_pd['Tweets Ago'][0], sentiments_pd['Compound'][0], color='blue', edgecolors='black', s=50, label="New York Times")
plt.scatter(sentiments_pd['Tweets Ago'][1], sentiments_pd['Compound'][1], color='yellow', edgecolors='black', s=50, label="BBC")
plt.scatter(sentiments_pd['Tweets Ago'][2], sentiments_pd['Compound'][2], color='red', edgecolors='black', s=50, label="CNN")
plt.scatter(sentiments_pd['Tweets Ago'][3], sentiments_pd['Compound'][3], color='green', edgecolors='black', s=50, label='FoxNews')
plt.scatter(sentiments_pd['Tweets Ago'][4], sentiments_pd['Compound'][4], color='purple', edgecolors='black', s=50, label='CBSNews')
plt.title(f"Sentiment Analysis of Media Tweets (" + date + ")")
plt.ylabel("Tweet Polarity")
plt.xlabel("Media Outlet")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))
plt.show()

# %%
# @nytimes, @BBC, @CNN, @FoxNews, @CBSNews

target_users = ("@NYtimes", "@BBC", "@CNN", "@FoxNews", "@CBSNews")

# List for dictionaries of results
results_list = []

# Loop through each user
for user in target_users:

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Loop through 100 tweets
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(user, page=x, count=100)

        # Loop through all tweets
        for tweet in public_tweets:

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]

            # Add each value to the appropriate list
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)

    # Create a dictionaty of results
    user_results = {
        "Username": user,
        "Compound Score": np.mean(compound_list),
        "Postive Score": np.mean(positive_list),
        "Neutral Score": np.mean(neutral_list),
        "Negative Score": np.mean(negative_list)
    }

    # Append dictionary to list
    results_list.append(user_results)

    # Print the Averages
    print(f"User: {user}")
    print(f"Compound: {np.mean(compound_list):.3f}")
    print(f"Positive: {np.mean(positive_list):.3f}")
    print(f"Neutral: {np.mean(neutral_list):.3f}")
    print(f"Negative: {np.mean(negative_list):.3f}")
# Out:
# User: @NYtimes
# Compound: -0.008
# Positive: 0.065
# Neutral: 0.867
# Negative: 0.068
# User: @BBC
# Compound: 0.111
# Positive: 0.102
# Neutral: 0.839
# Negative: 0.058
# User: @CNN
# Compound: -0.029
# Positive: 0.064
# Neutral: 0.862
# Negative: 0.073
# User: @FoxNews
# Compound: -0.023
# Positive: 0.065
# Neutral: 0.853
# Negative: 0.082
# User: @CBSNews
# Compound: -0.063
# Positive: 0.063
# Neutral: 0.839
# Negative: 0.098

# %%
# Create DataFrame from Results List
results_df = pd.DataFrame(results_list).set_index("Username").round(3)
results_df
# Out:
#           Compound Score  Negative Score  Neutral Score  Postive Score
# Username
# @NYtimes          -0.008           0.068          0.867          0.065
# @BBC               0.111           0.058          0.839          0.102
# @CNN              -0.029           0.073          0.862          0.064
# @FoxNews          -0.023           0.082          0.853          0.065
# @CBSNews          -0.063           0.098          0.839          0.063

# %%
colors = ['blue', 'yellow', 'red', 'green', 'purple']

date = time.strftime("%m/%d/%Y")

plt.bar(results_df.index, results_df['Compound Score'], color=colors, width=.9)
plt.title("Overall Media Sentiment on Twitter (" + date + ")")
plt.ylabel("Tweet Polarity")
plt.grid(False)
plt.show()
